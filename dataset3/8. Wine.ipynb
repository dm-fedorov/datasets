# %%
Citation Request:
  This dataset is public available for research. The details are described in [Cortez et al., 2009]. 
  Please include this citation if you plan to use this database:

  P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis. 
  Modeling wine preferences by data mining from physicochemical properties.
  In Decision Support Systems, Elsevier, 47(4):547-553. ISSN: 0167-9236.

  Available at: [@Elsevier] http://dx.doi.org/10.1016/j.dss.2009.05.016
                [Pre-press (pdf)] http://www3.dsi.uminho.pt/pcortez/winequality09.pdf
                [bib] http://www3.dsi.uminho.pt/pcortez/dss09.bib

1. Title: Wine Quality 

2. Sources
   Created by: Paulo Cortez (Univ. Minho), Antonio Cerdeira, Fernando Almeida, Telmo Matos and Jose Reis (CVRVV) @ 2009
   
3. Past Usage:

  P. Cortez, A. Cerdeira, F. Almeida, T. Matos and J. Reis. 
  Modeling wine preferences by data mining from physicochemical properties.
  In Decision Support Systems, Elsevier, 47(4):547-553. ISSN: 0167-9236.

В приведенной выше ссылке были созданы два набора данных с использованием образцов красного и белого вина. Входные данные включают в себя объективные тесты (например, значения PH), а выходные данные основаны на сенсорных данных (в среднем не менее 3 оценок, сделанных винными экспертами). Каждый эксперт оценил качество вина от 0 (очень плохо) до 10 (отлично). Несколько методов анализа данных были применены к данных в рамках регрессионного подхода. Модель машины опорных векторов достигла лучших результатов. Было рассчитано несколько метрик: MAD, матрица путаницы для фиксированной погрешности (T), и т.д. Кроме того, Кроме того, мы описали относительную важность входных.
 
4. Полезная информация:

   Два дата сета относятся к красному и белому виду португальского вина "Vinho Verde".
   For more details, consult: http://www.vinhoverde.pt/en/ or the reference [Cortez et al., 2009].
   Из-за проблем конфиденциальности и логистики, только физико-химические (входные) и сенсорные (выходные) переменные
   доступны (например, нет данных о типах винограда, марке вина, цене продажи вина и т. д.).
   Эти дата сеты могут быть рассмотрены как задачи классификации или регрессии.
   Классы отсортированы и не сбалансированы (т.е. в нем гораздо больше обычных вин нежели
   отличных или плохих). Outlier detection algorithms может быть использован для обнаружения нескольких отличных или плохих вин.
   Также, мы не уверены, что все параметры релевантны. Так что было бы интересно попробовать методы выбора параметров.

5. Количество наблюдений: красные вина - 1599; белые вина - 4898. 

6. Количество параметров: 11 независимых + 1 зависимый
  
   Заметка: Некоторые параметры могу коррелировать, следовательно, было бы логично попытаться применить какой-нибудь метод выбора параметров.

7. Информация о параметрах:

   Для большего количества информации, читайте:  [Cortez et al., 2009].

   Входные переменные (основанные на физико-химических данных):
   1 – фиксированная кислотность;
   2 - летучая кислотность;
   3 – лимонная кислота;
   4 - остаточный сахар;
   5 – хлориды;
   6 - свободный диоксид серы;
   7 - общий диоксид серы;
   8 – плотность;
   9 – Водородный показатель (мера кислотности);
   10 – сульфаты;
   11 – алкоголь;
   Результирующая переменная;
   12 – качество (от 0 до 10).

8. Пропущенные значения: Отсутствуют.
