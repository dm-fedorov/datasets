# %% [markdown]
# <center>
# # Набор Данных о Сверхпроводимости

# %% [markdown]
# ## Имеется два файла:
# ### (1) train.csv содержит 81 элемент, извлеченный из 21263 сверхпроводников вместе с критической температурой в 82-м столбце
# ### (2) unique_m.csv содержит химическую формулу, разбитую для всех 21263 сверхпроводников из train.csv файл. Последние два столбца имеют критическую температуру и химическую формулу. Исходные данные взяты из Web Link, которая является общедоступной. Цель - предсказать критическую температуру на основе извлеченных особенностей.
#
# Ссылка на dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/00464/
#
# Доп. информ: https://www.sciencedirect.com/science/article/pii/S0927025618304877?via%3Dihub

# %% [markdown]
# ### Название Столбцов в dataset train
#
# 'number_of_elements' - количество элементов
#
# 'mean_atomic_mass' - средняя атомная масса
#
# 'wtd_mean_atomic_mass' - средняя атомная масса
#
# 'gmean_atomic_mass' - средняя геометрическая атомная масса
#
# 'wtd_gmean_atomic_mass' - wtd средняя геометрическая атомная масса
#
# 'entropy_atomic_mass' - энтропия атомная масса
#
# 'wtd_entropy_atomic_mass' - атомная масса отклонения веса
#
# 'range_atomic_mass' -  атомная масса диапазона
#
# 'wtd_range_atomic_mass' -  атомная масса диапазона wtd
#
# 'std_atomic_mass' -  стандартная атомная масса
#
# 'wtd_std_atomic_mass' -  wtd стандартная атомная масса
#
# 'mean_fie' - среднее значение в парамагнитной фазе fie
#
# 'wtd_mean_fie' - wtd среднее значение в парамагнитной фазе fie
#
# 'gmean_fie' - средняя геометрическая в парамагнитной фазе fie
#
# 'wtd_gmean_fie' - wtd средняя геометрическая в парамагнитной фазе fie
#
# 'entropy_fie' - энтропия в парамагнитной фазе fie
#
# 'wtd_entropy_fie' - wtd энтропия в парамагнитной фазе fie
#
# 'range_fie' - спектр в парамагнитной фазе fie
#
# 'wtd_range_fie' - wtd спектр в парамагнитной фазе fie
#
# 'std_fie' - стандартное отклонение в парамагнитной фазе fie
#
# 'wtd_std_fie', - wtd стандартного отклонения в парамагнитной фазе fie
#
# 'mean_atomic_radius' - средний атомный радиус
#
# 'wtd_mean_atomic_radius' -  wtd средний атомный радиус
#
# 'gmean_atomic_radius' -  среднее геометрическое атомного радиуса
#
# 'wtd_gmean_atomic_radius' -  wtd среднее геометрическое атомный радиус
#
# 'entropy_atomic_radius' - энтропия атомного радиуса
#
# 'wtd_entropy_atomic_radius' - wtd энтропии атомного радиуса
#
# 'range_atomic_radius' -  дальность атомного радиуса
#
# 'wtd_range_atomic_radius' -  атомный радиус диапазона wtd
#
# 'std_atomic_radius' - стандартное отклонение атомного радиуса
#
# 'wtd_std_atomic_radius' - wtd стандартное отклонение атомного радиуса
#
# 'mean_Density' - средняя плотность
#
# 'wtd_mean_Density' - wtd средняя плотность
#
# 'gmean_Density' - среднее геометрическое плотности
#
# 'wtd_gmean_Density' - wtd среднее геометрическое плотности
#
# 'entropy_Density' - плотность энтропии
#
# 'wtd_entropy_Density'- wtd плотность энтропии
#
# 'range_Density' - Плотность диапазона
#
# 'wtd_range_Density' - Плотность диапазона wtd
#
# 'std_Density' - плотность стандартного отклонения
#
# 'wtd_std_Density' - wtd плотность стандартного отклонения
#
# 'mean_ElectronAffinity' - среднее значенее электронного сродства
#
# 'wtd_mean_ElectronAffinity' - wtd среднее значение электронного сродства
#
# 'gmean_ElectronAffinity' - среднее геометрическое значение электронного сродства
#
# 'wtd_gmean_ElectronAffinity' - wtd среднее геометрическое значение электронного сродства
#
# 'entropy_ElectronAffinity' - энтропия электронного сродства
#
# 'wtd_entropy_ElectronAffinity' - wtd энтропии электронного сродства
#
# 'range_ElectronAffinity' - диапазон электронного сродства
#
# 'wtd_range_ElectronAffinity' - wtd диапазон электронного сродства
#
# 'std_ElectronAffinity' - стандартное отклонение электронного сродства
#
# 'wtd_std_ElectronAffinity' - wtd стандартное отклонение электронного сродства
#
# 'mean_FusionHeat' - среденее значения плавления при высокой температуре
#
# 'wtd_mean_FusionHeat' - wtd среденее значения плавления при высокой температуре
#
# 'gmean_FusionHeat' - среднее геометрическое плавления при высокой температуре
#
# 'wtd_gmean_FusionHeat'- wtd среднее геометрическое плавления при высокой температуре
#
# 'entropy_FusionHeat' - энтропия плавления при высокой температуре
#
# 'wtd_entropy_FusionHeat' - wtd  энтропия плавления при высокой температуре
#
# 'range_FusionHeat' - диапозон плавления при высокой температуре
#
# 'wtd_range_FusionHeat' - wtd диапозон плавления при высокой температуре
#
# 'std_FusionHeat' - стандартное отклонение плавления при высокой температуре
#
# 'wtd_std_FusionHeat' - wtd стандартное отклонение плавления при высокой температуре
#
# 'mean_ThermalConductivity' - среднее значение теплопроводности
#
# 'wtd_mean_ThermalConductivity' - wtd среднее значение теплопроводности
#
# 'gmean_ThermalConductivity' - среднее геометрическое значение теплопроводности
#
# 'wtd_gmean_ThermalConductivity' - wtd среднее геометрическое значение теплопроводности
#
# 'entropy_ThermalConductivity' - энтропия теплопроводности
#
# 'wtd_entropy_ThermalConductivity' - wtd энтропия теплопроводности
#
# 'range_ThermalConductivity' - диапозон теплопроводности
#
# 'wtd_range_ThermalConductivity' - wtd диапозон теплопроводности
#
# 'std_ThermalConductivity' - стандартное отклонение теплопроводности
#
# 'wtd_std_ThermalConductivity' - wtd стандартное отклонение теплопроводности
#
# 'mean_Valence' - средняя валентность
#
# 'wtd_mean_Valence' - wtd средняя валентность
#
# 'gmean_Valence' - среднее геометрическое валентности
#
# 'wtd_gmean_Valence' - wtd среднее геометрическое валентности
#
# 'entropy_Valence' - энтропия валентности
#
# 'wtd_entropy_Valence' - wtd энтропия валентности
#
# 'range_Valence' - диапозон валентности
#
# 'wtd_range_Valence' - wtd диапозона валентности
#
# 'std_Valence' - стандартное отклонение валентности
#
# 'wtd_std_Valence' - wtd стандартное отклонение валентности
#
# 'critical_temp' - критическая температура

# %% [markdown]
# #### Характеристики Набора Данных: многомерные
# #### Характеристики Атрибутов: целые и реальные числа
# #### Задача: регрессии
# #### Количество строк: 21263
# #### Количестно признаков: 81
# #### Пропущенные значения: отсутствуют
# #### Область: физика
# #### Дата сбора выборки: 12.10.2018
# #### Количество обращений: 17458
# #### Источник: Kam Ham idieh, khamidieh@gmail.com , Университет Пенсильвании, статистика

# %%
import pandas as pd

train=pd.read_csv('train.csv')
unique_m=pd.read_csv('unique_m.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 82 columns):
# number_of_elements                 21263 non-null int64
# mean_atomic_mass                   21263 non-null float64
# wtd_mean_atomic_mass               21263 non-null float64
# gmean_atomic_mass                  21263 non-null float64
# wtd_gmean_atomic_mass              21263 non-null float64
# entropy_atomic_mass                21263 non-null float64
# wtd_entropy_atomic_mass            21263 non-null float64
# range_atomic_mass                  21263 non-null float64
# wtd_range_atomic_mass              21263 non-null float64
# std_atomic_mass                    21263 non-null float64
# wtd_std_atomic_mass                21263 non-null float64
# mean_fie                           21263 non-null float64
# wtd_mean_fie                       21263 non-null float64
# gmean_fie                          21263 non-null float64
# ...

# %%
unique_m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21263 entries, 0 to 21262
# Data columns (total 88 columns):
# H                21263 non-null float64
# He               21263 non-null int64
# Li               21263 non-null float64
# Be               21263 non-null float64
# B                21263 non-null float64
# C                21263 non-null float64
# N                21263 non-null float64
# O                21263 non-null float64
# F                21263 non-null float64
# Ne               21263 non-null int64
# Na               21263 non-null float64
# Mg               21263 non-null float64
# Al               21263 non-null float64
# Si               21263 non-null float64
# P                21263 non-null float64
# S                21263 non-null float64
# Cl               21263 non-null float64
# Ar               21263 non-null int64
# K                21263 non-null float64
# Ca               21263 non-null float64
# Sc               21263 non-null float64
# ...
