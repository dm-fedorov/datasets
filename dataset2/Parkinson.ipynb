# %% [markdown]
# <center>
# # Набор данных классификации болезней Паркинсона

# %% [markdown]
# # Информация О Наборе Данных:
#
# ### Данные, использованные в данном исследовании, были получены от 188 пациентов с БП (107 мужчин и 81 женщина) в возрасте от 33 до 87 (65,1 а±10,9) на кафедре неврологии Медицинского факультета Cerrahpaåa Стамбульского университета.
# ### Контрольная группа состоит из 64 здоровых лиц (23 мужчины и 41 женщина) в возрасте от 41 до 82 лет (61,1 а±8,9).
# ### Во время процесса сбора данных, микрофон установлен на 44,1 кГц и после осмотра physicianâ€™с, устойчивый фон гласной /a/ был собран от каждого субъекта с тремя повторениями.
# ### Для речевых записей пациентов с болезнью Паркинсона (ПД) были применены различные алгоритмы обработки речевых сигналов, в том числе временные частотные характеристики, коэффициенты Кэпстрала Mel, особенности на основе вейвлет-преобразования, особенности вокальной складки и особенности TWQT, чтобы извлечь клинически полезную информацию для оценки ПД.
#
# #### Характеристики Набора Данных: многомерные
# #### Характеристики Атрибутов:  целые и реальные числа
# #### Задача: классификации
# #### Количество строк: 756
# #### Количестно признаков: 754
# #### Пропущенные значения: отсутствуют
# #### Область: Медицина
# #### Дата сбора выборки: 05.11.2018
# #### Количество обращений: 12076
#
# Ссылка на dataset: https://archive.ics.uci.edu/ml/machine-learning-databases/00470/

# %%
import pandas as pd

speech_features=pd.read_csv('pd_speech_features.csv')
